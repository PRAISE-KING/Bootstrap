# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAISE-KING/Bootstrap/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
dataset = pandas.read_csv("https://modcom.co.ke/data/datasets/Advertising.csv")
dataset
# Out:
#       No     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
dataset.shape
# Out:
# (200, 5)

# %%
dataset.describe()
# Out:
#                No          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
subset = dataset[["TV", "Radio", "Newspaper", "Sales"]] 
#subset - introduced to reduce number of columns to be used.in this case "No."" was unnecessary.can also use other names e.g y,z or praiz etc
subset
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
array = subset.values

# %%
X = array[:,0:3]
Y = array[:, 3]
Y
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 12.5,
#         5.6, 15.5,  9.7, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,
#        17.4,  9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9,
#         8.5, 14.9, 10.6, 23.2, 14.8,  9.7, 11.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 15.7, 14. , 18. ,  9.3,
#         9.5, 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12. , 16. ,
#        12.9, 16.7, 11.2,  7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4,
#        17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2,  7.2,  8.7,  5.3, 19.8,
#        13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 11.6, 15.2, 19.7, 10.6,  6.6,  8.8, 24.7,  9.7,  1.6, 12.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
# ...

# %%
dataset.values
# Out:
# array([[  1. , 230.1,  37.8,  69.2,  22.1],
#        [  2. ,  44.5,  39.3,  45.1,  10.4],
#        [  3. ,  17.2,  45.9,  69.3,   9.3],
#        [  4. , 151.5,  41.3,  58.5,  18.5],
#        [  5. , 180.8,  10.8,  58.4,  12.9],
#        [  6. ,   8.7,  48.9,  75. ,   7.2],
#        [  7. ,  57.5,  32.8,  23.5,  11.8],
#        [  8. , 120.2,  19.6,  11.6,  13.2],
#        [  9. ,   8.6,   2.1,   1. ,   4.8],
#        [ 10. , 199.8,   2.6,  21.2,  10.6],
#        [ 11. ,  66.1,   5.8,  24.2,   8.6],
#        [ 12. , 214.7,  24. ,   4. ,  17.4],
#        [ 13. ,  23.8,  35.1,  65.9,   9.2],
#        [ 14. ,  97.5,   7.6,   7.2,   9.7],
#        [ 15. , 204.1,  32.9,  46. ,  19. ],
#        [ 16. , 195.4,  47.7,  52.9,  22.4],
#        [ 17. ,  67.8,  36.6, 114. ,  12.5],
#        [ 18. , 281.4,  39.6,  55.8,  24.4],
#        [ 19. ,  69.2,  20.5,  18.3,  11.3],
#        [ 20. , 147.3,  23.9,  19.1,  14.6],
#        [ 21. , 218.4,  27.7,  53.4,  18. ],
# ...

# %%
from sklearn import model_selection #model_selection used to split data into training sets(70%) and testing sets(30%)

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.30, random_state=40)

# %%
# algorithms

from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

# %%
model = KNeighborsRegressor()
model.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
predictions = model.predict(X_test)
print("The model predicted : ", predictions)
# Out:
# The correct answer is : [13.24  7.58 12.4  14.12 23.98 15.   19.    8.94 11.74  9.16 18.82 19.96
#  13.92 15.66 14.74  9.58 16.16 13.12  6.08 13.88 11.84 19.16 17.7  22.46
#  12.38  7.6  10.64 16.62  6.7   6.3  17.58 10.3  17.04 14.12 16.36  6.76
#  14.5  20.9  12.36 22.12 10.56  8.9  21.84 10.56 17.54 13.5  17.02 15.38
#  17.88 10.18 24.18  8.76 11.26 15.08  9.48 16.34 13.46 21.12 11.02  8.4 ]

# %%
print("The correct answer is :", Y_test)
# Out:
# The correct answer is : [11.7  7.2 12.2 12.8 26.2 14.4 20.2 10.8 11.2  9.9 20.7 20.1 11.7 15.
#  16.7 10.9 14.5 15.5  5.7 14.7 11.6 18.9 15.2 22.2 11.5  8.7 11.3 19.2
#   7.   1.6 17.4 10.6 17.1 15.  17.4  8.  12.3 21.8 13.4 25.4 12.   8.7
#  22.3 10.6 20.7 14.2 15.7 15.6 18.4 10.9 27.   9.7 10.4 18.   9.7 16.6
#  14.1 22.6 10.3  9.5]

# %%
# evaluation - the closeness of model prediction to the real answer (r2_score)

from sklearn.metrics import r2_score
print("the accuracy is : ", r2_score(predictions, Y_test)*100)
# Out:
# the accuracy is :  89.53190819585046

# %%
dataset.head(2)
# Out:
#    No     TV  Radio  Newspaper  Sales
# 0   1  230.1   37.8       69.2   22.1
# 1   2   44.5   39.3       45.1   10.4

# %%
# predictions

adverts = [[250.3,40.4,73.3,]]
sales_gained = model.predict(adverts)
print("The sales incresed by : ", sales_gained)
# Out:
# The sales incresed by :  [22.46]
